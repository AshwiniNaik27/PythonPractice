# %% [markdown]
# <a href="https://colab.research.google.com/github/AshwiniNaik27/PythonPractice/blob/main/calPract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number=int(input ("enter 3 digit number"))
a=(number//100)
print("a :",a)
b=((number//10)%10)
print("b :",b)
c=((number)%10)
print("c :",c)
print("sum =",(a+b+c))
print("sum : ",sum)
# Out:
# enter 3 digit number123
# a : 1
# b : 2
# c : 3
# sum = 6
# sum :  6

# %%
number=int(input ("enter 3 digit number"))
a=(number//100)
b=((number//10)%10)
c=((number)%10)
print("sum =",(a+b+c))
print("SUM :", (number//100)+((number//10)%10)+((number)%10))
# Out:
# enter 3 digit number123
# sum = 6
# SUM : 6
